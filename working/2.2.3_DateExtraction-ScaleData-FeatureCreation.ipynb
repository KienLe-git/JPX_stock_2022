# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xgboost as xgb
import time
from sklearn.metrics import mean_squared_error

'''
None || 20000 || 100000
'''
nb = None
nb_trains = nb
nb_valids = nb
nb_tests = nb

N_past = 10

# %%
# from google.colab import drive
# drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# cd drive/MyDrive/Projects/JPX_Tokyo_Stock/JPX_stock_2022/working
# Out:
# /content/drive/MyDrive/Projects/JPX_Tokyo_Stock/JPX_stock_2022/working

# %%
! pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting optuna
#   Downloading optuna-2.10.1-py3-none-any.whl (308 kB)
#      |████████████████████████████████| 308 kB 5.0 MB/s
# Collecting cmaes>=0.8.2
#   Downloading cmaes-0.8.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna) (4.64.0)
# Collecting cliff
#   Downloading cliff-3.10.1-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 9.2 MB/s
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.7.3)
# Collecting alembic
#   Downloading alembic-1.8.1-py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 93.9 MB/s
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from optuna) (3.13)
# Collecting colorlog
#   Downloading colorlog-6.6.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.39)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from optuna) (1.21.6)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (1.1.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (4.12.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (5.8.0)
# Collecting Mako
#   Downloading Mako-1.2.1-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 8.1 MB/s
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.3.0)
# Collecting stevedore>=2.0.1
#   Downloading stevedore-3.5.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 7.1 MB/s
# Collecting autopage>=0.4.0
#   Downloading autopage-0.5.1-py3-none-any.whl (29 kB)
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.9.0-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 64.1 MB/s
# Collecting cmd2>=1.0.0
#   Downloading cmd2-2.4.2-py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 10.2 MB/s
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (21.4.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (4.1.1)
# Collecting pyperclip>=1.6
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy>=1.1.0->optuna) (3.8.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna) (2.0.1)
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11137 sha256=44939d0f15374ff18fd41544407fadd5d797fdebf34679a794330e17352a4e23
#   Stored in directory: /root/.cache/pip/wheels/9f/18/84/8f69f8b08169c7bae2dde6bd7daf0c19fca8c8e500ee620a28
# Successfully built pyperclip
# Installing collected packages: pyperclip, pbr, stevedore, Mako, cmd2, autopage, colorlog, cmaes, cliff, alembic, optuna
# Successfully installed Mako-1.2.1 alembic-1.8.1 autopage-0.5.1 cliff-3.10.1 cmaes-0.8.2 cmd2-2.4.2 colorlog-6.6.0 optuna-2.10.1 pbr-5.9.0 pyperclip-1.8.2 stevedore-3.5.0

# %%
import optuna
from data_utils import *

# %% [markdown]
# #### Load Data

# %%
train_df = pd.read_csv('../__input__/2_FeatureEngineering/train_df.csv', parse_dates=['Date'], nrows = nb_trains)
valid_df = pd.read_csv('../__input__/2_FeatureEngineering/valid_df.csv', parse_dates=['Date'], nrows = nb_trains)
test_df = pd.read_csv('../__input__/2_FeatureEngineering/test_df.csv', parse_dates=['Date'], nrows = nb_trains)

# %%
mini_train_DP = pd.read_csv('../__input__/1_DataPreprocessing/mini_train.csv', parse_dates=['Date'], nrows = None)
mini_train_FE = pd.read_csv('../__input__/2_FeatureEngineering/mini_train.csv', parse_dates=['Date'], nrows = None)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1843182 entries, 0 to 1843181
# Data columns (total 64 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Date              datetime64[ns]
#  1   SecuritiesCode    int64
#  2   ExpectedDividend  float64
#  3   AdjustmentFactor  float64
#  4   SupervisionFlag   bool
#  5   Volume            float64
#  6   Close             float64
#  7   Target            float64
#  8   CloseT1           float64
#  9   CloseT2           float64
#  10  Range_HL          float64
#  11  Range_OC          float64
#  12  dayofyear         int64
#  13  dayofweek         int64
#  14  week              int64
#  15  is_month_end      bool
#  16  is_month_start    bool
#  17  is_year_end       bool
#  18  is_year_start     bool
#  19  Year              int64
#  20  Month             int64
#  21  Day               int64
#  22  Close_lags_1      float64
#  23  Range_HL_lags_1   float64
#  24  Range_OC_lags_1   float64
#  25  Volume_lags_1     float64
#  26  Close_lags_2      float64
#  27  Range_HL_lags_2   float64
#  28  Range_OC_lags_2   float64
#  29  Volume_lags_2     float64
#  30  Close_lags_3      float64
#  31  Range_HL_lags_3   float64
#  32  Range_OC_lags_3   float64
#  33  Volume_lags_3     float64
#  34  Close_lags_4      float64
#  35  Range_HL_lags_4   float64
#  36  Range_OC_lags_4   float64
#  37  Volume_lags_4     float64
#  38  Close_lags_5      float64
#  39  Range_HL_lags_5   float64
#  40  Range_OC_lags_5   float64
#  41  Volume_lags_5     float64
#  42  Close_lags_6      float64
#  43  Range_HL_lags_6   float64
#  44  Range_OC_lags_6   float64
#  45  Volume_lags_6     float64
#  46  Close_lags_7      float64
#  47  Range_HL_lags_7   float64
#  48  Range_OC_lags_7   float64
#  49  Volume_lags_7     float64
#  50  Close_lags_8      float64
#  51  Range_HL_lags_8   float64
#  52  Range_OC_lags_8   float64
#  53  Volume_lags_8     float64
#  54  Close_lags_9      float64
#  55  Range_HL_lags_9   float64
#  56  Range_OC_lags_9   float64
#  57  Volume_lags_9     float64
#  58  Close_lags_10     float64
#  59  Range_HL_lags_10  float64
#  60  Range_OC_lags_10  float64
#  61  Volume_lags_10    float64
#  62  Close_mean        float64
#  63  Close_std         float64
# dtypes: bool(5), datetime64[ns](1), float64(51), int64(7)
# memory usage: 838.5 MB

# %%
valid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232663 entries, 0 to 232662
# Data columns (total 64 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              232663 non-null  datetime64[ns]
#  1   SecuritiesCode    232663 non-null  int64
#  2   ExpectedDividend  232663 non-null  float64
#  3   AdjustmentFactor  232663 non-null  float64
#  4   SupervisionFlag   232663 non-null  bool
#  5   Volume            232663 non-null  float64
#  6   Close             232663 non-null  float64
#  7   Target            232663 non-null  float64
#  8   CloseT1           232663 non-null  float64
#  9   CloseT2           232663 non-null  float64
#  10  Range_HL          232663 non-null  float64
#  11  Range_OC          232663 non-null  float64
#  12  dayofyear         232663 non-null  int64
#  13  dayofweek         232663 non-null  int64
#  14  week              232663 non-null  int64
#  15  is_month_end      232663 non-null  bool
#  16  is_month_start    232663 non-null  bool
#  17  is_year_end       232663 non-null  bool
#  18  is_year_start     232663 non-null  bool
#  19  Year              232663 non-null  int64
#  20  Month             232663 non-null  int64
#  21  Day               232663 non-null  int64
#  22  Close_lags_1      232663 non-null  float64
#  23  Range_HL_lags_1   232663 non-null  float64
#  24  Range_OC_lags_1   232663 non-null  float64
#  25  Volume_lags_1     232663 non-null  float64
#  26  Close_lags_2      232663 non-null  float64
#  27  Range_HL_lags_2   232663 non-null  float64
#  28  Range_OC_lags_2   232663 non-null  float64
#  29  Volume_lags_2     232663 non-null  float64
#  30  Close_lags_3      232663 non-null  float64
#  31  Range_HL_lags_3   232663 non-null  float64
#  32  Range_OC_lags_3   232663 non-null  float64
#  33  Volume_lags_3     232663 non-null  float64
#  34  Close_lags_4      232663 non-null  float64
#  35  Range_HL_lags_4   232663 non-null  float64
#  36  Range_OC_lags_4   232663 non-null  float64
#  37  Volume_lags_4     232663 non-null  float64
#  38  Close_lags_5      232663 non-null  float64
#  39  Range_HL_lags_5   232663 non-null  float64
#  40  Range_OC_lags_5   232663 non-null  float64
#  41  Volume_lags_5     232663 non-null  float64
#  42  Close_lags_6      232663 non-null  float64
#  43  Range_HL_lags_6   232663 non-null  float64
#  44  Range_OC_lags_6   232663 non-null  float64
#  45  Volume_lags_6     232663 non-null  float64
#  46  Close_lags_7      232663 non-null  float64
#  47  Range_HL_lags_7   232663 non-null  float64
#  48  Range_OC_lags_7   232663 non-null  float64
#  49  Volume_lags_7     232663 non-null  float64
#  50  Close_lags_8      232663 non-null  float64
#  51  Range_HL_lags_8   232663 non-null  float64
#  52  Range_OC_lags_8   232663 non-null  float64
#  53  Volume_lags_8     232663 non-null  float64
#  54  Close_lags_9      232663 non-null  float64
#  55  Range_HL_lags_9   232663 non-null  float64
#  56  Range_OC_lags_9   232663 non-null  float64
#  57  Volume_lags_9     232663 non-null  float64
#  58  Close_lags_10     232663 non-null  float64
#  59  Range_HL_lags_10  232663 non-null  float64
#  60  Range_OC_lags_10  232663 non-null  float64
#  61  Volume_lags_10    232663 non-null  float64
#  62  Close_mean        232663 non-null  float64
#  63  Close_std         232663 non-null  float64
# dtypes: bool(5), datetime64[ns](1), float64(51), int64(7)
# memory usage: 105.8 MB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198663 entries, 0 to 198662
# Data columns (total 64 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              198663 non-null  datetime64[ns]
#  1   SecuritiesCode    198663 non-null  int64
#  2   ExpectedDividend  198663 non-null  float64
#  3   AdjustmentFactor  198663 non-null  float64
#  4   SupervisionFlag   198663 non-null  bool
#  5   Volume            198663 non-null  float64
#  6   Close             198663 non-null  float64
#  7   Target            198663 non-null  float64
#  8   CloseT1           198663 non-null  float64
#  9   CloseT2           198663 non-null  float64
#  10  Range_HL          198663 non-null  float64
#  11  Range_OC          198663 non-null  float64
#  12  dayofyear         198663 non-null  int64
#  13  dayofweek         198663 non-null  int64
#  14  week              198663 non-null  int64
#  15  is_month_end      198663 non-null  bool
#  16  is_month_start    198663 non-null  bool
#  17  is_year_end       198663 non-null  bool
#  18  is_year_start     198663 non-null  bool
#  19  Year              198663 non-null  int64
#  20  Month             198663 non-null  int64
#  21  Day               198663 non-null  int64
#  22  Close_lags_1      198663 non-null  float64
#  23  Range_HL_lags_1   198663 non-null  float64
#  24  Range_OC_lags_1   198663 non-null  float64
#  25  Volume_lags_1     198663 non-null  float64
#  26  Close_lags_2      198663 non-null  float64
#  27  Range_HL_lags_2   198663 non-null  float64
#  28  Range_OC_lags_2   198663 non-null  float64
#  29  Volume_lags_2     198663 non-null  float64
#  30  Close_lags_3      198663 non-null  float64
#  31  Range_HL_lags_3   198663 non-null  float64
#  32  Range_OC_lags_3   198663 non-null  float64
#  33  Volume_lags_3     198663 non-null  float64
#  34  Close_lags_4      198663 non-null  float64
#  35  Range_HL_lags_4   198663 non-null  float64
#  36  Range_OC_lags_4   198663 non-null  float64
#  37  Volume_lags_4     198663 non-null  float64
#  38  Close_lags_5      198663 non-null  float64
#  39  Range_HL_lags_5   198663 non-null  float64
#  40  Range_OC_lags_5   198663 non-null  float64
#  41  Volume_lags_5     198663 non-null  float64
#  42  Close_lags_6      198663 non-null  float64
#  43  Range_HL_lags_6   198663 non-null  float64
#  44  Range_OC_lags_6   198663 non-null  float64
#  45  Volume_lags_6     198663 non-null  float64
#  46  Close_lags_7      198663 non-null  float64
#  47  Range_HL_lags_7   198663 non-null  float64
#  48  Range_OC_lags_7   198663 non-null  float64
#  49  Volume_lags_7     198663 non-null  float64
#  50  Close_lags_8      198663 non-null  float64
#  51  Range_HL_lags_8   198663 non-null  float64
#  52  Range_OC_lags_8   198663 non-null  float64
#  53  Volume_lags_8     198663 non-null  float64
#  54  Close_lags_9      198663 non-null  float64
#  55  Range_HL_lags_9   198663 non-null  float64
#  56  Range_OC_lags_9   198663 non-null  float64
#  57  Volume_lags_9     198663 non-null  float64
#  58  Close_lags_10     198663 non-null  float64
#  59  Range_HL_lags_10  198663 non-null  float64
#  60  Range_OC_lags_10  198663 non-null  float64
#  61  Volume_lags_10    198663 non-null  float64
#  62  Close_mean        198663 non-null  float64
#  63  Close_std         198663 non-null  float64
# dtypes: bool(5), datetime64[ns](1), float64(51), int64(7)
# memory usage: 90.4 MB

# %% [markdown]
# ### Calc Scores

# %%
def calc_spread_return_per_day(df, portfolio_size: int = 200, toprank_weight_ratio: float = 2):
    """
    Args:
        df (pd.DataFrame): predicted results
        portfolio_size (int): # of equities to buy/sell
        toprank_weight_ratio (float): the relative weight of the most highly ranked stock compared to the least.
    Returns:
        (float): spread return
    """
    assert df['Rank'].min() == 0
    assert df['Rank'].max() == len(df['Rank']) - 1
    weights = np.linspace(start=toprank_weight_ratio, stop=1, num=portfolio_size)
    purchase = (df.sort_values(by='Rank')['Target'][:portfolio_size] * weights).sum() / weights.mean()
    short = (df.sort_values(by='Rank', ascending=False)['Target'][:portfolio_size] * weights).sum() / weights.mean()
    return purchase - short

def calc_spread_return_sharpe(df: pd.DataFrame, portfolio_size: int = 200, toprank_weight_ratio: float = 2) -> float:
    """
    Args:
        df (pd.DataFrame): predicted results
        portfolio_size (int): # of equities to buy/sell
        toprank_weight_ratio (float): the relative weight of the most highly ranked stock compared to the least.
    Returns:
        (float): sharpe ratio
    """
    buf = df.groupby('Date').apply(calc_spread_return_per_day, portfolio_size, toprank_weight_ratio)
    sharpe_ratio = buf.mean() / buf.std()
    return sharpe_ratio, buf

def add_rank(df: pd.DataFrame, y_pred):
    df["Pred"] = y_pred
    df["Rank"] = df.groupby("Date")["Pred"].rank(ascending=False, method="first") - 1 
    df = df.drop("Pred", axis= 1)
    return df

# %%
def calc_score(df: pd.DataFrame, y_pred: pd.DataFrame, y_true: pd.DataFrame, render_info= True):
    feature_df = df.copy()
    feature_df = add_rank(feature_df, y_pred)
    feature_df['Target'] = y_true
    score, buf = calc_spread_return_sharpe(feature_df)
    if render_info:
        print(f'score -> {score}\nmean -> {buf.mean()}\nstd -> {buf.std()}')
    del feature_df
    return score

# %%
calc_score(test_df, test_df["Target"], test_df["Target"])
# Out:
# score -> 4.7366694709759
# mean -> 15.115996128121251
# std -> 3.1912710440838277
# 4.7366694709759

# %% [markdown]
# ### Cross Validation

# %%
featureCols = train_df.drop(["Target", "CloseT1", "CloseT2"], axis = 1).columns
featureCols
# Out:
# Index(['Date', 'SecuritiesCode', 'ExpectedDividend', 'AdjustmentFactor',
#        'SupervisionFlag', 'Volume', 'Close', 'Range_HL', 'Range_OC',
#        'dayofyear', 'dayofweek', 'week', 'is_month_end', 'is_month_start',
#        'is_year_end', 'is_year_start', 'Year', 'Month', 'Day', 'Close_lags_1',
#        'Range_HL_lags_1', 'Range_OC_lags_1', 'Volume_lags_1', 'Close_lags_2',
#        'Range_HL_lags_2', 'Range_OC_lags_2', 'Volume_lags_2', 'Close_lags_3',
#        'Range_HL_lags_3', 'Range_OC_lags_3', 'Volume_lags_3', 'Close_lags_4',
#        'Range_HL_lags_4', 'Range_OC_lags_4', 'Volume_lags_4', 'Close_lags_5',
#        'Range_HL_lags_5', 'Range_OC_lags_5', 'Volume_lags_5', 'Close_lags_6',
#        'Range_HL_lags_6', 'Range_OC_lags_6', 'Volume_lags_6', 'Close_lags_7',
#        'Range_HL_lags_7', 'Range_OC_lags_7', 'Volume_lags_7', 'Close_lags_8',
#        'Range_HL_lags_8', 'Range_OC_lags_8', 'Volume_lags_8', 'Close_lags_9',
#        'Range_HL_lags_9', 'Range_OC_lags_9', 'Volume_lags_9', 'Close_lags_10',
#        'Range_HL_lags_10', 'Range_OC_lags_10', 'Volume_lags_10', 'Close_mean',
#        'Close_std'],
#       dtype='object')

# %%
X_train = train_df[featureCols]
X_train["Date"] = X_train["Date"].astype(str)
y_train = train_df["Target"]

X_valid = valid_df[featureCols]
X_valid["Date"] = X_valid["Date"].astype(str)
y_valid = valid_df["Target"]

X_test = test_df[featureCols]
X_test["Date"] = X_test["Date"].astype(str)
yTest_true = test_df["Target"]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
calc_score(X_test, yTest_true, yTest_true)
# Out:
# score -> 4.7366694709759
# mean -> 15.115996128121251
# std -> 3.1912710440838277
# 4.7366694709759

# %% [markdown]
# #### Optuna tuning

# %%
def objective(
    trial,
    random_state=22,
    n_jobs=-1,
):
    # XGBoost parameters
    params = {
        'tree_method':'gpu_hist',
        "verbosity": 0,  # 0 (silent) - 3 (debug)
        "objective": "reg:squarederror",
        "n_estimators": trial.suggest_int("n_estimators", 5, 10) * 100,
        "max_depth": trial.suggest_int("max_depth", 4, 20),
        "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.05),
        "colsample_bytree": trial.suggest_loguniform("colsample_bytree", 0.2, 0.6),
        "subsample": trial.suggest_loguniform("subsample", 0.6, 0.8),
        "alpha": trial.suggest_loguniform("alpha", 0.01, 10.0),
        "lambda": trial.suggest_loguniform("lambda", 1e-8, 10.0),
        "gamma": trial.suggest_loguniform("lambda", 1e-8, 10.0),
        "min_child_weight": trial.suggest_loguniform("min_child_weight", 10, 1000),
        "seed": random_state,
        "n_jobs": n_jobs,
        "early_stopping_rounds": 50,
        "eval_metric": "rmse"
        
    }
    
    model = xgb.XGBRegressor(**params) 

    model.fit(
        X_train.drop("Date", axis = 1),
        y_train,
        eval_set=[(X_valid.drop("Date", axis = 1), y_valid)],
        verbose=0,
    )
    y_pred = pd.DataFrame(model.predict(X_valid.drop("Date", axis = 1)), columns =['Target'])
    return calc_score(X_valid, y_pred, y_valid, render_info= False)

# %%
# %%time
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=30)
print('Number of finished trials:', len(study.trials))
print('Best trial:', study.best_trial.params)
# Out:
# [I 2022-07-20 00:58:30,574] A new study created in memory with name: no-name-ef5d9f2a-493e-4a4b-ab63-15ee0087a98f
# [I 2022-07-20 00:59:03,859] Trial 0 finished with value: 0.15000313759537068 and parameters: {'n_estimators': 5, 'max_depth': 4, 'learning_rate': 0.021021661074885827, 'colsample_bytree': 0.36851707463448463, 'subsample': 0.6266570684964355, 'alpha': 0.8298100546710911, 'lambda': 5.017379582701743e-06, 'min_child_weight': 393.6376966574984}. Best is trial 0 with value: 0.15000313759537068.
# [I 2022-07-20 01:00:11,903] Trial 1 finished with value: 0.18851695943464214 and parameters: {'n_estimators': 7, 'max_depth': 11, 'learning_rate': 0.028930218553966245, 'colsample_bytree': 0.5750599592017832, 'subsample': 0.7097357691137528, 'alpha': 0.1971914552899138, 'lambda': 1.143740002941748e-08, 'min_child_weight': 578.5394746577219}. Best is trial 1 with value: 0.18851695943464214.
# [I 2022-07-20 01:01:50,852] Trial 2 finished with value: 0.21713465858500314 and parameters: {'n_estimators': 9, 'max_depth': 13, 'learning_rate': 0.027583249037077633, 'colsample_bytree': 0.3415355148729672, 'subsample': 0.77601716967931, 'alpha': 7.939793180089097, 'lambda': 2.9161386329762714e-07, 'min_child_weight': 598.3416692560019}. Best is trial 2 with value: 0.21713465858500314.
# [I 2022-07-20 01:04:15,793] Trial 3 finished with value: 0.2910795821564993 and parameters: {'n_estimators': 10, 'max_depth': 15, 'learning_rate': 0.01809612584067924, 'colsample_bytree': 0.2857109693471447, 'subsample': 0.7352976005406506, 'alpha': 0.026644721113400185, 'lambda': 8.509332381343536e-07, 'min_child_weight': 338.7776859066026}. Best is trial 3 with value: 0.2910795821564993.
# [I 2022-07-20 01:05:45,966] Trial 4 finished with value: 0.184182028932281 and parameters: {'n_estimators': 7, 'max_depth': 14, 'learning_rate': 0.012487736767517979, 'colsample_bytree': 0.2498280513199678, 'subsample': 0.6633126134778264, 'alpha': 0.051909293729176284, 'lambda': 0.00010207422021505192, 'min_child_weight': 817.2159012851531}. Best is trial 3 with value: 0.2910795821564993.
# [I 2022-07-20 01:06:28,956] Trial 5 finished with value: 0.09592634529077397 and parameters: {'n_estimators': 7, 'max_depth': 5, 'learning_rate': 0.021405175830467527, 'colsample_bytree': 0.583209793428649, 'subsample': 0.7589064780433129, 'alpha': 0.6714959360021127, 'lambda': 0.27053654880219163, 'min_child_weight': 42.15148167295985}. Best is trial 3 with value: 0.2910795821564993.
# [I 2022-07-20 01:08:37,691] Trial 6 finished with value: 0.24306374864007524 and parameters: {'n_estimators': 8, 'max_depth': 14, 'learning_rate': 0.026655399100255172, 'colsample_bytree': 0.5716242708848469, 'subsample': 0.6760252768656904, 'alpha': 0.02376418444900503, 'lambda': 0.0001946887468870382, 'min_child_weight': 50.32870694348533}. Best is trial 3 with value: 0.2910795821564993.
# [I 2022-07-20 01:15:12,191] Trial 7 finished with value: 0.28251554746346463 and parameters: {'n_estimators': 6, 'max_depth': 19, 'learning_rate': 0.04917810953081492, 'colsample_bytree': 0.22336158663530292, 'subsample': 0.7533216156624752, 'alpha': 1.6755146012734965, 'lambda': 7.2699956960015445e-06, 'min_child_weight': 16.725608936805177}. Best is trial 3 with value: 0.2910795821564993.
# [I 2022-07-20 01:16:35,377] Trial 8 finished with value: 0.15386266020071887 and parameters: {'n_estimators': 5, 'max_depth': 17, 'learning_rate': 0.006691661081890525, 'colsample_bytree': 0.2833691037302788, 'subsample': 0.6728281381302793, 'alpha': 0.4514989015728595, 'lambda': 1.084073910679575e-06, 'min_child_weight': 273.2209606556578}. Best is trial 3 with value: 0.2910795821564993.
# [I 2022-07-20 01:20:26,580] Trial 9 finished with value: 0.2069148526607369 and parameters: {'n_estimators': 10, 'max_depth': 19, 'learning_rate': 0.03851955954953431, 'colsample_bytree': 0.24337533008863832, 'subsample': 0.6667078609757165, 'alpha': 0.06883985630741012, 'lambda': 4.4137985439802263e-07, 'min_child_weight': 176.15672349574731}. Best is trial 3 with value: 0.2910795821564993.
# [I 2022-07-20 01:21:50,096] Trial 10 finished with value: 0.19431703793619337 and parameters: {'n_estimators': 10, 'max_depth': 9, 'learning_rate': 0.011156443675144883, 'colsample_bytree': 0.41622857810413244, 'subsample': 0.723016554155191, 'alpha': 0.010282555269825005, 'lambda': 0.20136663667066382, 'min_child_weight': 115.84422374172273}. Best is trial 3 with value: 0.2910795821564993.
# [I 2022-07-20 01:30:20,033] Trial 11 finished with value: 0.26147051179352065 and parameters: {'n_estimators': 6, 'max_depth': 20, 'learning_rate': 0.04677376069402267, 'colsample_bytree': 0.20170385676880903, 'subsample': 0.7433459177202025, 'alpha': 3.407787936338993, 'lambda': 0.0082098058073607, 'min_child_weight': 14.16795233837439}. Best is trial 3 with value: 0.2910795821564993.
# [I 2022-07-20 01:35:05,353] Trial 12 finished with value: 0.18914445190751675 and parameters: {'n_estimators': 8, 'max_depth': 17, 'learning_rate': 0.005053619515323613, 'colsample_bytree': 0.20380764251521105, 'subsample': 0.7911456814047519, 'alpha': 1.774734466413034, 'lambda': 1.5763989023940082e-05, 'min_child_weight': 13.477967775531017}. Best is trial 3 with value: 0.2910795821564993.
# [I 2022-07-20 01:38:34,311] Trial 13 finished with value: 0.2550469892205528 and parameters: {'n_estimators': 6, 'max_depth': 17, 'learning_rate': 0.014957812092363583, 'colsample_bytree': 0.28350604888231673, 'subsample': 0.7348089110208947, 'alpha': 0.14254476026022184, 'lambda': 2.6776330983492993e-08, 'min_child_weight': 39.29835667364624}. Best is trial 3 with value: 0.2910795821564993.
# [I 2022-07-20 01:42:16,792] Trial 14 finished with value: 0.2122729155195117 and parameters: {'n_estimators': 9, 'max_depth': 16, 'learning_rate': 0.008438125412982887, 'colsample_bytree': 0.24393830411939954, 'subsample': 0.7075399175513006, 'alpha': 1.6939288304545437, 'lambda': 0.0035083244524935415, 'min_child_weight': 89.62093781169798}. Best is trial 3 with value: 0.2910795821564993.
# [I 2022-07-20 01:43:18,381] Trial 15 finished with value: 0.25086681213483236 and parameters: {'n_estimators': 6, 'max_depth': 10, 'learning_rate': 0.04577868385257035, 'colsample_bytree': 0.30497819848392804, 'subsample': 0.7616679839571951, 'alpha': 7.224544478144427, 'lambda': 8.702250715654971, 'min_child_weight': 25.314181431060174}. Best is trial 3 with value: 0.2910795821564993.
# [I 2022-07-20 01:46:38,661] Trial 16 finished with value: 0.23759417431815705 and parameters: {'n_estimators': 9, 'max_depth': 19, 'learning_rate': 0.018011367660133684, 'colsample_bytree': 0.4480921224367618, 'subsample': 0.7963456796050087, 'alpha': 0.012038440887803311, 'lambda': 1.8468499830738122e-05, 'min_child_weight': 216.77126048330402}. Best is trial 3 with value: 0.2910795821564993.
# [I 2022-07-20 01:47:34,933] Trial 17 finished with value: 0.13921953205248266 and parameters: {'n_estimators': 8, 'max_depth': 7, 'learning_rate': 0.0343458329753589, 'colsample_bytree': 0.22779013269342, 'subsample': 0.631070435271659, 'alpha': 0.23093538077256706, 'lambda': 9.834502780490689e-08, 'min_child_weight': 107.51958798771612}. Best is trial 3 with value: 0.2910795821564993.
# [I 2022-07-20 01:51:05,461] Trial 18 finished with value: 0.15604646465898445 and parameters: {'n_estimators': 6, 'max_depth': 16, 'learning_rate': 0.008926968181767685, 'colsample_bytree': 0.3170365544490026, 'subsample': 0.7440109426144551, 'alpha': 0.09828827565673465, 'lambda': 3.678460612410504e-06, 'min_child_weight': 10.316351533032222}. Best is trial 3 with value: 0.2910795821564993.
# [I 2022-07-20 01:55:21,091] Trial 19 finished with value: 0.3673461052101412 and parameters: {'n_estimators': 10, 'max_depth': 15, 'learning_rate': 0.015107646108550874, 'colsample_bytree': 0.27525012231668355, 'subsample': 0.6895054632161345, 'alpha': 0.03121626887114335, 'lambda': 0.000415355382658415, 'min_child_weight': 20.815622011274296}. Best is trial 19 with value: 0.3673461052101412.
# [I 2022-07-20 01:57:39,342] Trial 20 finished with value: 0.24446915367650576 and parameters: {'n_estimators': 10, 'max_depth': 12, 'learning_rate': 0.013568397318310757, 'colsample_bytree': 0.2755813627766749, 'subsample': 0.695405378291467, 'alpha': 0.03334315659777972, 'lambda': 0.002078822745788864, 'min_child_weight': 25.571286030574658}. Best is trial 19 with value: 0.3673461052101412.
# [I 2022-07-20 02:01:44,320] Trial 21 finished with value: 0.1842650998252399 and parameters: {'n_estimators': 10, 'max_depth': 15, 'learning_rate': 0.019616516019853144, 'colsample_bytree': 0.2240044440936252, 'subsample': 0.6000347646065538, 'alpha': 0.023685977679827115, 'lambda': 0.00010120951303101413, 'min_child_weight': 22.68317462600597}. Best is trial 19 with value: 0.3673461052101412.
# [I 2022-07-20 02:07:31,504] Trial 22 finished with value: 0.24633621564612143 and parameters: {'n_estimators': 9, 'max_depth': 19, 'learning_rate': 0.00982592512416584, 'colsample_bytree': 0.2678687769638027, 'subsample': 0.7167543868007493, 'alpha': 0.04451854141291509, 'lambda': 0.0004933765606585103, 'min_child_weight': 67.25706654570547}. Best is trial 19 with value: 0.3673461052101412.
# [I 2022-07-20 02:10:17,996] Trial 23 finished with value: 0.20590310581095772 and parameters: {'n_estimators': 10, 'max_depth': 13, 'learning_rate': 0.016117899740849814, 'colsample_bytree': 0.3198969646156725, 'subsample': 0.6893894579840072, 'alpha': 0.016923971381462753, 'lambda': 1.2506643509033891e-05, 'min_child_weight': 16.29488431200968}. Best is trial 19 with value: 0.3673461052101412.
# [I 2022-07-20 02:13:50,856] Trial 24 finished with value: 0.22662205170776262 and parameters: {'n_estimators': 9, 'max_depth': 15, 'learning_rate': 0.02293342001157974, 'colsample_bytree': 0.258947649690379, 'subsample': 0.7616396431398351, 'alpha': 0.09384363701743763, 'lambda': 0.019508046787646883, 'min_child_weight': 32.428849831439706}. Best is trial 19 with value: 0.3673461052101412.
# [I 2022-07-20 02:16:36,925] Trial 25 finished with value: 0.20504732849310595 and parameters: {'n_estimators': 5, 'max_depth': 18, 'learning_rate': 0.03522136994291606, 'colsample_bytree': 0.2270578717093954, 'subsample': 0.6477787693277786, 'alpha': 0.33543981683736634, 'lambda': 1.706796569707431e-06, 'min_child_weight': 65.29383645002068}. Best is trial 19 with value: 0.3673461052101412.
# [I 2022-07-20 02:20:23,021] Trial 26 finished with value: 0.23036474154622347 and parameters: {'n_estimators': 8, 'max_depth': 20, 'learning_rate': 0.017236057408031125, 'colsample_bytree': 0.35779385249765205, 'subsample': 0.7289208970091781, 'alpha': 1.1819957071899998, 'lambda': 4.807987514335736e-05, 'min_child_weight': 155.12205005968985}. Best is trial 19 with value: 0.3673461052101412.
# [I 2022-07-20 02:25:10,913] Trial 27 finished with value: 0.2645147618244971 and parameters: {'n_estimators': 10, 'max_depth': 15, 'learning_rate': 0.0076222688231068, 'colsample_bytree': 0.29957513101875116, 'subsample': 0.6900062057289201, 'alpha': 3.403784555706625, 'lambda': 0.0007279019304559962, 'min_child_weight': 10.237315031070725}. Best is trial 19 with value: 0.3673461052101412.
# [I 2022-07-20 02:26:57,324] Trial 28 finished with value: 0.18240104596243054 and parameters: {'n_estimators': 7, 'max_depth': 12, 'learning_rate': 0.011343324855150563, 'colsample_bytree': 0.2108611973658229, 'subsample': 0.7474303712463263, 'alpha': 0.029356908730701677, 'lambda': 1.1092663222331725e-07, 'min_child_weight': 19.937391114632955}. Best is trial 19 with value: 0.3673461052101412.
# [I 2022-07-20 02:28:35,780] Trial 29 finished with value: 0.2682887087707681 and parameters: {'n_estimators': 5, 'max_depth': 18, 'learning_rate': 0.024984730028262327, 'colsample_bytree': 0.3856381085366055, 'subsample': 0.7733101460608135, 'alpha': 0.4511928302383119, 'lambda': 3.1377246358602985e-06, 'min_child_weight': 359.95848444780995}. Best is trial 19 with value: 0.3673461052101412.
# Number of finished trials: 30
# Best trial: {'n_estimators': 10, 'max_depth': 15, 'learning_rate': 0.015107646108550874, 'colsample_bytree': 0.27525012231668355, 'subsample': 0.6895054632161345, 'alpha': 0.03121626887114335, 'lambda': 0.000415355382658415, 'min_child_weight': 20.815622011274296}
# CPU times: user 1h 29min 33s, sys: 55.8 s, total: 1h 30min 29s
# Wall time: 1h 30min 5s

# %%
# best_params = {
# 'max_depth': 19, 
# 'learning_rate': 0.025941339430375736, 
# 'colsample_bytree': 0.23703603495974382, 
# 'subsample': 0.623891935763922, 
# 'alpha': 0.011194397798498705, 
# 'lambda': 5.016592593209065e-08, 
# 'min_child_weight': 10.273750710892847,
#  'early_stopping_rounds': 50,
#  'eval_metric': 'rmse',
#  'n_estimators': 1000,
#  'n_jobs': -1,
#  'objective': 'reg:squarederror',
#  'seed': 22,
#  'tree_method': 'gpu_hist',
#  'verbosity': 0}

# best_params

# %%
best_params = study.best_trial.params
best_params['n_estimators'] *= 100

best_params['tree_method'] = 'gpu_hist'
best_params['verbosity'] = 0
best_params['objective'] = "reg:squarederror"
best_params['seed'] = 22
best_params['n_jobs'] = -1
best_params["early_stopping_rounds"] = 50
best_params["eval_metric"] = "rmse"

best_params
# Out:
# {'alpha': 0.03121626887114335,
#  'colsample_bytree': 0.27525012231668355,
#  'early_stopping_rounds': 50,
#  'eval_metric': 'rmse',
#  'lambda': 0.000415355382658415,
#  'learning_rate': 0.015107646108550874,
#  'max_depth': 15,
#  'min_child_weight': 20.815622011274296,
#  'n_estimators': 1000,
#  'n_jobs': -1,
#  'objective': 'reg:squarederror',
#  'seed': 22,
#  'subsample': 0.6895054632161345,
#  'tree_method': 'gpu_hist',
#  'verbosity': 0}

# %%
# %%time
model = xgb.XGBRegressor(**best_params) 

model.fit(
    X_train.drop("Date", axis = 1),
    y_train,
    eval_set=[(X_valid.drop("Date", axis = 1), y_valid)],
    verbose=0,
)
# Out:
# CPU times: user 4min 12s, sys: 1.7 s, total: 4min 14s
# Wall time: 4min 13s

# %%
# %%time
y_pred = pd.DataFrame(model.predict(X_train.drop("Date", axis = 1)), columns =['Target'])
print(calc_score(X_train, y_pred, y_train, render_info= False))
# Out:
# 3.8921991113597705
# CPU times: user 13.6 s, sys: 1.33 s, total: 14.9 s
# Wall time: 14.8 s

# %%
np.sqrt(mean_squared_error(y_pred, y_train))
# Out:
# 0.017113496108677736

# %%
# %%time
y_pred = pd.DataFrame(model.predict(X_valid.drop("Date", axis = 1)), columns =['Target'])
print(calc_score(X_valid, y_pred, y_valid, render_info= False))
# Out:
# 0.2585777768849355
# CPU times: user 1.66 s, sys: 163 ms, total: 1.82 s
# Wall time: 1.81 s

# %%
np.sqrt(mean_squared_error(y_pred, y_valid))
# Out:
# 0.021426365407683952

# %%
# %%time
y_pred = pd.DataFrame(model.predict(X_test.drop("Date", axis = 1)), columns =['Target'])
print(calc_score(X_test, y_pred, yTest_true, render_info= False))
# Out:
# 0.12102818230523413
# CPU times: user 1.43 s, sys: 155 ms, total: 1.59 s
# Wall time: 1.58 s

# %%
np.sqrt(mean_squared_error(y_pred, yTest_true))
# Out:
# 0.024571998744342165

# %%
def render_feature_important(model_xgboost, df_trained):
  feature_important = model_xgboost.feature_importances_
  sorted_idx = np.argsort(feature_important)[::-1]

  keys = df_trained.columns[sorted_idx]
  values = feature_important[sorted_idx]

  data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=True)
  data.plot(kind='barh', figsize = (20,10))

# %%
render_feature_important(model, X_train.drop("Date", axis = 1))
