# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import xgboost as xgb
import time
from sklearn.metrics import mean_squared_error

'''
None || 20000 || 100000
'''
nb = None
nb_trains = nb
nb_valids = nb
nb_tests = nb

N_past = 10

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
cd drive/MyDrive/Projects/JPX_Tokyo_Stock/working
# Out:
# /content/drive/MyDrive/Projects/JPX_Tokyo_Stock/working

# %%
! pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: optuna in /usr/local/lib/python3.7/dist-packages (2.10.1)
# Requirement already satisfied: cmaes>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from optuna) (0.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna) (4.64.0)
# Requirement already satisfied: cliff in /usr/local/lib/python3.7/dist-packages (from optuna) (3.10.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (21.3)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.7/dist-packages (from optuna) (6.6.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from optuna) (1.21.6)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from optuna) (3.13)
# Requirement already satisfied: alembic in /usr/local/lib/python3.7/dist-packages (from optuna) (1.8.0)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.37)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (4.11.4)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (1.1.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (1.2.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (5.7.1)
# Requirement already satisfied: autopage>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (0.5.1)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.3.0)
# Requirement already satisfied: cmd2>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (2.4.1)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (5.9.0)
# Requirement already satisfied: stevedore>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.5.0)
# Requirement already satisfied: pyperclip>=1.6 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (1.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (4.1.1)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (21.4.0)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy>=1.1.0->optuna) (3.8.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna) (2.0.1)

# %%
import optuna
from data_utils import *

# %% [markdown]
# #### Load Data

# %%
train_df = pd.read_csv('../input/2_after_featureEgineering/' + str(N_past) + '/train_full.csv', parse_dates=['Date'], nrows = nb_trains)
valid_df = pd.read_csv('../input/2_after_featureEgineering/' + str(N_past) + '/valid_full.csv', parse_dates=['Date'], nrows = nb_valids)
test_df = pd.read_csv('../input/2_after_featureEgineering/' + str(N_past) + '/test_full.csv', parse_dates=['Date'], nrows = nb_tests)
y_test_df = pd.read_csv('../input/2_after_featureEgineering/' + str(N_past) + '/y_test_full.csv', parse_dates=['Date'], nrows = nb_tests)

official_test_df = pd.read_csv('../input/jpx-tokyo-stock-exchange-prediction/example_test_files/stock_prices.csv', nrows = None, parse_dates=['Date'])

# %%
mini_train_after_dataPreprocessing = pd.read_csv('../input/1_after_datapreprocessing/mini_train.csv', parse_dates=['Date'], nrows = None)
mini_train_after_featureEngineering = pd.read_csv('../input/2_after_featureEgineering/' + str(N_past) + '/mini_train.csv', parse_dates=['Date'], nrows = None)

# %%
official_test_df = FeatureEgineering_for_official_test(DataPreprocessing_for_official_test(official_test_df, mini_train_after_dataPreprocessing), mini_train_after_featureEngineering, N_past)
# Out:
# /content/drive/MyDrive/Projects/JPX_Tokyo_Stock/working/data_utils.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_return['ExpectedDividend'] = df_return['ExpectedDividend'].fillna(-1)
# /usr/local/lib/python3.7/dist-packages/pandas/core/arraylike.py:364: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4573509 entries, 0 to 4573508
# Data columns (total 64 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Date                datetime64[ns]
#  1   SecuritiesCode      int64
#  2   Volume              float64
#  3   AdjustmentFactor    float64
#  4   ExpectedDividend    float64
#  5   SupervisionFlag     bool
#  6   Target              float64
#  7   CloseT2             float64
#  8   Close               float64
#  9   CloseT1             float64
#  10  Range_HL            float64
#  11  Range_OC            float64
#  12  dayofyear           int64
#  13  dayofweek           int64
#  14  week                int64
#  15  is_month_end        bool
#  16  is_month_start      bool
#  17  is_year_end         bool
#  18  is_year_start       bool
#  19  Year                int64
#  20  Month               int64
#  21  Day                 int64
#  22  Close_1_before      float64
#  23  Range_HL_1_before   float64
#  24  Range_OC_1_before   float64
#  25  Volume_1_before     float64
#  26  Close_2_before      float64
#  27  Range_HL_2_before   float64
#  28  Range_OC_2_before   float64
#  29  Volume_2_before     float64
#  30  Close_3_before      float64
#  31  Range_HL_3_before   float64
#  32  Range_OC_3_before   float64
#  33  Volume_3_before     float64
#  34  Close_4_before      float64
#  35  Range_HL_4_before   float64
#  36  Range_OC_4_before   float64
#  37  Volume_4_before     float64
#  38  Close_5_before      float64
#  39  Range_HL_5_before   float64
#  40  Range_OC_5_before   float64
#  41  Volume_5_before     float64
#  42  Close_6_before      float64
#  43  Range_HL_6_before   float64
#  44  Range_OC_6_before   float64
#  45  Volume_6_before     float64
#  46  Close_7_before      float64
#  47  Range_HL_7_before   float64
#  48  Range_OC_7_before   float64
#  49  Volume_7_before     float64
#  50  Close_8_before      float64
#  51  Range_HL_8_before   float64
#  52  Range_OC_8_before   float64
#  53  Volume_8_before     float64
#  54  Close_9_before      float64
#  55  Range_HL_9_before   float64
#  56  Range_OC_9_before   float64
#  57  Volume_9_before     float64
#  58  Close_10_before     float64
#  59  Range_HL_10_before  float64
#  60  Range_OC_10_before  float64
#  61  Volume_10_before    float64
#  62  Close_mean          float64
#  63  Close_std           float64
# dtypes: bool(5), datetime64[ns](1), float64(51), int64(7)
# memory usage: 2.0 GB

# %%
valid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233223 entries, 0 to 233222
# Data columns (total 64 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Date                233223 non-null  datetime64[ns]
#  1   SecuritiesCode      233223 non-null  int64
#  2   Volume              233223 non-null  float64
#  3   AdjustmentFactor    233223 non-null  float64
#  4   ExpectedDividend    233223 non-null  float64
#  5   SupervisionFlag     233223 non-null  bool
#  6   Target              233223 non-null  float64
#  7   CloseT2             233223 non-null  float64
#  8   Close               233223 non-null  float64
#  9   CloseT1             233223 non-null  float64
#  10  Range_HL            233223 non-null  float64
#  11  Range_OC            233223 non-null  float64
#  12  dayofyear           233223 non-null  int64
#  13  dayofweek           233223 non-null  int64
#  14  week                233223 non-null  int64
#  15  is_month_end        233223 non-null  bool
#  16  is_month_start      233223 non-null  bool
#  17  is_year_end         233223 non-null  bool
#  18  is_year_start       233223 non-null  bool
#  19  Year                233223 non-null  int64
#  20  Month               233223 non-null  int64
#  21  Day                 233223 non-null  int64
#  22  Close_1_before      233223 non-null  float64
#  23  Range_HL_1_before   233223 non-null  float64
#  24  Range_OC_1_before   233223 non-null  float64
#  25  Volume_1_before     233223 non-null  float64
#  26  Close_2_before      233223 non-null  float64
#  27  Range_HL_2_before   233223 non-null  float64
#  28  Range_OC_2_before   233223 non-null  float64
#  29  Volume_2_before     233223 non-null  float64
#  30  Close_3_before      233223 non-null  float64
#  31  Range_HL_3_before   233223 non-null  float64
#  32  Range_OC_3_before   233223 non-null  float64
#  33  Volume_3_before     233223 non-null  float64
#  34  Close_4_before      233223 non-null  float64
#  35  Range_HL_4_before   233223 non-null  float64
#  36  Range_OC_4_before   233223 non-null  float64
#  37  Volume_4_before     233223 non-null  float64
#  38  Close_5_before      233223 non-null  float64
#  39  Range_HL_5_before   233223 non-null  float64
#  40  Range_OC_5_before   233223 non-null  float64
#  41  Volume_5_before     233223 non-null  float64
#  42  Close_6_before      233223 non-null  float64
#  43  Range_HL_6_before   233223 non-null  float64
#  44  Range_OC_6_before   233223 non-null  float64
#  45  Volume_6_before     233223 non-null  float64
#  46  Close_7_before      233223 non-null  float64
#  47  Range_HL_7_before   233223 non-null  float64
#  48  Range_OC_7_before   233223 non-null  float64
#  49  Volume_7_before     233223 non-null  float64
#  50  Close_8_before      233223 non-null  float64
#  51  Range_HL_8_before   233223 non-null  float64
#  52  Range_OC_8_before   233223 non-null  float64
#  53  Volume_8_before     233223 non-null  float64
#  54  Close_9_before      233223 non-null  float64
#  55  Range_HL_9_before   233223 non-null  float64
#  56  Range_OC_9_before   233223 non-null  float64
#  57  Volume_9_before     233223 non-null  float64
#  58  Close_10_before     233223 non-null  float64
#  59  Range_HL_10_before  233223 non-null  float64
#  60  Range_OC_10_before  233223 non-null  float64
#  61  Volume_10_before    233223 non-null  float64
#  62  Close_mean          233223 non-null  float64
#  63  Close_std           233223 non-null  float64
# dtypes: bool(5), datetime64[ns](1), float64(51), int64(7)
# memory usage: 106.1 MB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229952 entries, 0 to 229951
# Data columns (total 61 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Date                229952 non-null  datetime64[ns]
#  1   SecuritiesCode      229952 non-null  int64
#  2   Volume              229952 non-null  float64
#  3   AdjustmentFactor    229952 non-null  float64
#  4   ExpectedDividend    229952 non-null  float64
#  5   SupervisionFlag     229952 non-null  bool
#  6   Close               229952 non-null  float64
#  7   Range_HL            229952 non-null  float64
#  8   Range_OC            229952 non-null  float64
#  9   dayofyear           229952 non-null  int64
#  10  dayofweek           229952 non-null  int64
#  11  week                229952 non-null  int64
#  12  is_month_end        229952 non-null  bool
#  13  is_month_start      229952 non-null  bool
#  14  is_year_end         229952 non-null  bool
#  15  is_year_start       229952 non-null  bool
#  16  Year                229952 non-null  int64
#  17  Month               229952 non-null  int64
#  18  Day                 229952 non-null  int64
#  19  Close_1_before      229952 non-null  float64
#  20  Range_HL_1_before   229952 non-null  float64
#  21  Range_OC_1_before   229952 non-null  float64
#  22  Volume_1_before     229952 non-null  float64
#  23  Close_2_before      229952 non-null  float64
#  24  Range_HL_2_before   229952 non-null  float64
#  25  Range_OC_2_before   229952 non-null  float64
#  26  Volume_2_before     229952 non-null  float64
#  27  Close_3_before      229952 non-null  float64
#  28  Range_HL_3_before   229952 non-null  float64
#  29  Range_OC_3_before   229952 non-null  float64
#  30  Volume_3_before     229952 non-null  float64
#  31  Close_4_before      229952 non-null  float64
#  32  Range_HL_4_before   229952 non-null  float64
#  33  Range_OC_4_before   229952 non-null  float64
#  34  Volume_4_before     229952 non-null  float64
#  35  Close_5_before      229952 non-null  float64
#  36  Range_HL_5_before   229952 non-null  float64
#  37  Range_OC_5_before   229952 non-null  float64
#  38  Volume_5_before     229952 non-null  float64
#  39  Close_6_before      229952 non-null  float64
#  40  Range_HL_6_before   229952 non-null  float64
#  41  Range_OC_6_before   229952 non-null  float64
#  42  Volume_6_before     229952 non-null  float64
#  43  Close_7_before      229952 non-null  float64
#  44  Range_HL_7_before   229952 non-null  float64
#  45  Range_OC_7_before   229952 non-null  float64
#  46  Volume_7_before     229952 non-null  float64
#  47  Close_8_before      229952 non-null  float64
#  48  Range_HL_8_before   229952 non-null  float64
#  49  Range_OC_8_before   229952 non-null  float64
#  50  Volume_8_before     229952 non-null  float64
#  51  Close_9_before      229952 non-null  float64
#  52  Range_HL_9_before   229952 non-null  float64
#  53  Range_OC_9_before   229952 non-null  float64
#  54  Volume_9_before     229952 non-null  float64
#  55  Close_10_before     229952 non-null  float64
#  56  Range_HL_10_before  229952 non-null  float64
#  57  Range_OC_10_before  229952 non-null  float64
#  58  Volume_10_before    229952 non-null  float64
#  59  Close_mean          229952 non-null  float64
#  60  Close_std           229952 non-null  float64
# dtypes: bool(5), datetime64[ns](1), float64(48), int64(7)
# memory usage: 99.3 MB

# %%
y_test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229952 entries, 0 to 229951
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   SecuritiesCode  229952 non-null  int64
#  1   Date            229952 non-null  datetime64[ns]
#  2   CloseT1         229952 non-null  float64
#  3   CloseT2         229952 non-null  float64
#  4   Target          229952 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1)
# memory usage: 8.8 MB

# %%
official_test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 61 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                4000 non-null   datetime64[ns]
#  1   SecuritiesCode      4000 non-null   int64
#  2   Volume              4000 non-null   float64
#  3   AdjustmentFactor    4000 non-null   float64
#  4   ExpectedDividend    4000 non-null   float64
#  5   SupervisionFlag     4000 non-null   bool
#  6   Close               4000 non-null   float64
#  7   Range_HL            4000 non-null   float64
#  8   Range_OC            4000 non-null   float64
#  9   dayofyear           4000 non-null   int64
#  10  dayofweek           4000 non-null   int64
#  11  week                4000 non-null   UInt32
#  12  is_month_end        4000 non-null   bool
#  13  is_month_start      4000 non-null   bool
#  14  is_year_end         4000 non-null   bool
#  15  is_year_start       4000 non-null   bool
#  16  Year                4000 non-null   int64
#  17  Month               4000 non-null   int64
#  18  Day                 4000 non-null   int64
#  19  Close_1_before      4000 non-null   float64
#  20  Range_HL_1_before   4000 non-null   float64
#  21  Range_OC_1_before   4000 non-null   float64
#  22  Volume_1_before     4000 non-null   float64
#  23  Close_2_before      4000 non-null   float64
#  24  Range_HL_2_before   4000 non-null   float64
#  25  Range_OC_2_before   4000 non-null   float64
#  26  Volume_2_before     4000 non-null   float64
#  27  Close_3_before      4000 non-null   float64
#  28  Range_HL_3_before   4000 non-null   float64
#  29  Range_OC_3_before   4000 non-null   float64
#  30  Volume_3_before     4000 non-null   float64
#  31  Close_4_before      4000 non-null   float64
#  32  Range_HL_4_before   4000 non-null   float64
#  33  Range_OC_4_before   4000 non-null   float64
#  34  Volume_4_before     4000 non-null   float64
#  35  Close_5_before      4000 non-null   float64
#  36  Range_HL_5_before   4000 non-null   float64
#  37  Range_OC_5_before   4000 non-null   float64
#  38  Volume_5_before     4000 non-null   float64
#  39  Close_6_before      4000 non-null   float64
#  40  Range_HL_6_before   4000 non-null   float64
#  41  Range_OC_6_before   4000 non-null   float64
#  42  Volume_6_before     4000 non-null   float64
#  43  Close_7_before      4000 non-null   float64
#  44  Range_HL_7_before   4000 non-null   float64
#  45  Range_OC_7_before   4000 non-null   float64
#  46  Volume_7_before     4000 non-null   float64
#  47  Close_8_before      4000 non-null   float64
#  48  Range_HL_8_before   4000 non-null   float64
#  49  Range_OC_8_before   4000 non-null   float64
#  50  Volume_8_before     4000 non-null   float64
#  51  Close_9_before      4000 non-null   float64
#  52  Range_HL_9_before   4000 non-null   float64
#  53  Range_OC_9_before   4000 non-null   float64
#  54  Volume_9_before     4000 non-null   float64
#  55  Close_10_before     4000 non-null   float64
#  56  Range_HL_10_before  4000 non-null   float64
#  57  Range_OC_10_before  4000 non-null   float64
#  58  Volume_10_before    4000 non-null   float64
#  59  Close_mean          4000 non-null   float64
#  60  Close_std           4000 non-null   float64
# dtypes: UInt32(1), bool(5), datetime64[ns](1), float64(48), int64(6)
# memory usage: 1.7 MB

# %% [markdown]
# ### Calc Scores

# %%
def calc_spread_return_per_day(df, portfolio_size: int = 200, toprank_weight_ratio: float = 2):
    """
    Args:
        df (pd.DataFrame): predicted results
        portfolio_size (int): # of equities to buy/sell
        toprank_weight_ratio (float): the relative weight of the most highly ranked stock compared to the least.
    Returns:
        (float): spread return
    """
    assert df['Rank'].min() == 0
    assert df['Rank'].max() == len(df['Rank']) - 1
    weights = np.linspace(start=toprank_weight_ratio, stop=1, num=portfolio_size)
    purchase = (df.sort_values(by='Rank')['Target'][:portfolio_size] * weights).sum() / weights.mean()
    short = (df.sort_values(by='Rank', ascending=False)['Target'][:portfolio_size] * weights).sum() / weights.mean()
    return purchase - short

def calc_spread_return_sharpe(df: pd.DataFrame, portfolio_size: int = 200, toprank_weight_ratio: float = 2) -> float:
    """
    Args:
        df (pd.DataFrame): predicted results
        portfolio_size (int): # of equities to buy/sell
        toprank_weight_ratio (float): the relative weight of the most highly ranked stock compared to the least.
    Returns:
        (float): sharpe ratio
    """
    buf = df.groupby('Date').apply(calc_spread_return_per_day, portfolio_size, toprank_weight_ratio)
    sharpe_ratio = buf.mean() / buf.std()
    return sharpe_ratio, buf

def add_rank(df: pd.DataFrame, y_pred):
    df["Pred"] = y_pred
    df["Rank"] = df.groupby("Date")["Pred"].rank(ascending=False, method="first") - 1 
    df = df.drop("Pred", axis= 1)
    return df

# %%
def calc_score(df: pd.DataFrame, y_pred: pd.DataFrame, y_true: pd.DataFrame, render_info= True):
    feature_df = df.copy()
    feature_df = add_rank(feature_df, y_pred)
    feature_df['Target'] = y_true
    score, buf = calc_spread_return_sharpe(feature_df)
    if render_info:
        print(f'score -> {score}\nmean -> {buf.mean()}\nstd -> {buf.std()}')
    del feature_df
    return score

# %%
calc_score(test_df, y_test_df["Target"], y_test_df["Target"])
# Out:
# score -> 4.687380919991682
# mean -> 15.446241603409499
# std -> 3.2952819211963917
# 4.687380919991682

# %% [markdown]
# ### Cross Validation

# %%
featureCols = train_df.drop(["Target", "CloseT1", "CloseT2"], axis = 1).columns
featureCols
# Out:
# Index(['Date', 'SecuritiesCode', 'Volume', 'AdjustmentFactor',
#        'ExpectedDividend', 'SupervisionFlag', 'Close', 'Range_HL', 'Range_OC',
#        'dayofyear', 'dayofweek', 'week', 'is_month_end', 'is_month_start',
#        'is_year_end', 'is_year_start', 'Year', 'Month', 'Day',
#        'Close_1_before', 'Range_HL_1_before', 'Range_OC_1_before',
#        'Volume_1_before', 'Close_2_before', 'Range_HL_2_before',
#        'Range_OC_2_before', 'Volume_2_before', 'Close_3_before',
#        'Range_HL_3_before', 'Range_OC_3_before', 'Volume_3_before',
#        'Close_4_before', 'Range_HL_4_before', 'Range_OC_4_before',
#        'Volume_4_before', 'Close_5_before', 'Range_HL_5_before',
#        'Range_OC_5_before', 'Volume_5_before', 'Close_6_before',
#        'Range_HL_6_before', 'Range_OC_6_before', 'Volume_6_before',
#        'Close_7_before', 'Range_HL_7_before', 'Range_OC_7_before',
#        'Volume_7_before', 'Close_8_before', 'Range_HL_8_before',
#        'Range_OC_8_before', 'Volume_8_before', 'Close_9_before',
#        'Range_HL_9_before', 'Range_OC_9_before', 'Volume_9_before',
#        'Close_10_before', 'Range_HL_10_before', 'Range_OC_10_before',
#        'Volume_10_before', 'Close_mean', 'Close_std'],
#       dtype='object')

# %%
X_train = train_df[featureCols]
X_train["Date"] = X_train["Date"].astype(str)
y_train = train_df["Target"]

X_valid = valid_df[featureCols]
X_valid["Date"] = X_valid["Date"].astype(str)
y_valid = valid_df["Target"]

X_test = test_df[featureCols]
X_test["Date"] = X_test["Date"].astype(str)
y_test = y_test_df["Target"]

del train_df, valid_df, y_test_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
calc_score(X_test, y_test, y_test)
# Out:
# score -> 4.687380919991682
# mean -> 15.446241603409499
# std -> 3.2952819211963917
# 4.687380919991682

# %% [markdown]
# #### Optuna tuning

# %%
x_train_optuna = X_train.drop("Date", axis = 1)
y_train_optuna = y_train
x_eval_optuna = X_valid
x_eval_not_date = X_valid.drop("Date", axis = 1)
y_eval_optuna = y_valid

# %%
def objective(
    trial,
    random_state=22,
    n_jobs=-1,
):
    # XGBoost parameters
    params = {
        'tree_method':'gpu_hist',
        "verbosity": 0,  # 0 (silent) - 3 (debug)
        "objective": "reg:squarederror",
        "n_estimators": 1000,
        "max_depth": trial.suggest_int("max_depth", 11, 25),
        "learning_rate": trial.suggest_loguniform("learning_rate", 0.005, 0.05),
        "colsample_bytree": trial.suggest_loguniform("colsample_bytree", 0.2, 0.6),
        "subsample": trial.suggest_loguniform("subsample", 0.6, 0.8),
        "alpha": trial.suggest_loguniform("alpha", 0.01, 10.0),
        "lambda": trial.suggest_loguniform("lambda", 1e-8, 10.0),
        "gamma": trial.suggest_loguniform("lambda", 1e-8, 10.0),
        "min_child_weight": trial.suggest_loguniform("min_child_weight", 10, 1000),
        "seed": random_state,
        "n_jobs": n_jobs,
        "early_stopping_rounds": 50,
        "eval_metric": "rmse"
        
    }

    model = xgb.XGBRegressor(**params) 

    model.fit(
        x_train_optuna,
        y_train_optuna,
        eval_set=[(x_eval_not_date, y_eval_optuna)],
        verbose=0,
    )
    y_pred = pd.DataFrame(model.predict(x_eval_not_date), columns =['Target'])
    del model
    return calc_score(x_eval_optuna, y_pred, y_eval_optuna, render_info= False)

# %%
# %%time
# study = optuna.create_study(direction='maximize')
# study.optimize(objective, n_trials=30, gc_after_trial=True)
# print('Number of finished trials:', len(study.trials))
# print('Best trial:', study.best_trial.params)

# %%
best_params = {
'max_depth': 19, 
'learning_rate': 0.025941339430375736, 
'colsample_bytree': 0.23703603495974382, 
'subsample': 0.623891935763922, 
'alpha': 0.011194397798498705, 
'lambda': 5.016592593209065e-08, 
'min_child_weight': 10.273750710892847,
 'early_stopping_rounds': 50,
 'eval_metric': 'rmse',
 'n_estimators': 1000,
 'n_jobs': -1,
 'objective': 'reg:squarederror',
 'seed': 22,
 'tree_method': 'gpu_hist',
 'verbosity': 0}

best_params
# Out:
# {'alpha': 0.011194397798498705,
#  'colsample_bytree': 0.23703603495974382,
#  'early_stopping_rounds': 50,
#  'eval_metric': 'rmse',
#  'lambda': 5.016592593209065e-08,
#  'learning_rate': 0.025941339430375736,
#  'max_depth': 19,
#  'min_child_weight': 10.273750710892847,
#  'n_estimators': 1000,
#  'n_jobs': -1,
#  'objective': 'reg:squarederror',
#  'seed': 22,
#  'subsample': 0.623891935763922,
#  'tree_method': 'gpu_hist',
#  'verbosity': 0}

# %%
# best_params = study.best_trial.params
# best_params['tree_method'] = 'gpu_hist'
# best_params['verbosity'] = 0
# best_params['objective'] = "reg:squarederror"
# best_params['n_estimators'] = 1000
# best_params['seed'] = 22
# best_params['n_jobs'] = -1
# best_params["early_stopping_rounds"] = 50
# best_params["eval_metric"] = "rmse"

# best_params

# %%
# %%time
model = xgb.XGBRegressor(**best_params) 

model.fit(
    X_train.drop("Date", axis = 1),
    y_train,
    eval_set=[(X_valid.drop("Date", axis = 1), y_valid)],
    verbose=0,
)
# Out:
# CPU times: user 18min 35s, sys: 11.8 s, total: 18min 47s
# Wall time: 18min 39s

# %%
# %%time
y_pred = pd.DataFrame(model.predict(X_train.drop("Date", axis = 1)), columns =['Target'])
print(calc_score(X_train, y_pred, y_train, render_info= False))
# Out:
# 4.6690860650609745
# CPU times: user 39.4 s, sys: 6.9 s, total: 46.3 s
# Wall time: 44.6 s

# %%
np.sqrt(mean_squared_error(y_pred, y_train))
# Out:
# 0.014998460712084362

# %%
# %%time
y_pred = pd.DataFrame(model.predict(X_valid.drop("Date", axis = 1)), columns =['Target'])
print(calc_score(X_valid, y_pred, y_valid, render_info= False))
# Out:
# 0.3624228254538214
# CPU times: user 2.33 s, sys: 248 ms, total: 2.58 s
# Wall time: 2.55 s

# %%
np.sqrt(mean_squared_error(y_pred, y_valid))
# Out:
# 0.02825101367012911

# %%
# %%time
y_pred = pd.DataFrame(model.predict(X_test.drop("Date", axis = 1)), columns =['Target'])
print(calc_score(X_test, y_pred, y_test, render_info= False))
# Out:
# 0.12944717668612396
# CPU times: user 2.32 s, sys: 213 ms, total: 2.53 s
# Wall time: 2.51 s

# %%
np.sqrt(mean_squared_error(y_pred, y_test))
# Out:
# 0.024845533419064238

# %%
def render_feature_important(model_xgboost, df_trained):
  feature_important = model_xgboost.feature_importances_
  sorted_idx = np.argsort(feature_important)[::-1]

  keys = df_trained.columns[sorted_idx]
  values = feature_important[sorted_idx]

  data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=True)
  data.plot(kind='barh', figsize = (20,10))

# %%
render_feature_important(model, X_train.drop("Date", axis = 1))

# %% [markdown]
# #### test pred official_test

# %%
official_test_df = pd.read_csv('../input/jpx-tokyo-stock-exchange-prediction/example_test_files/stock_prices.csv', nrows = None, parse_dates=['Date'])
mini_train_after_dataPreprocessing = pd.read_csv('../input/1_after_datapreprocessing/mini_train.csv', parse_dates=['Date'], nrows = None)

# %%
official_test_df

# %%
y_test_official = DataPreprocessing_for_official_test(official_test_df, mini_train_after_dataPreprocessing)
y_test_official
